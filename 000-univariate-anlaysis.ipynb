# %%
# !pip install jupyter_black
import jupyter_black
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
# Out:
# Requirement already satisfied: jupyter_black in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (0.3.4)
# Requirement already satisfied: black>=21 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from jupyter_black) (23.12.1)
# Requirement already satisfied: ipython>=7 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from jupyter_black) (8.12.0)
# Requirement already satisfied: tokenize-rt>=4 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from jupyter_black) (5.2.0)
# Requirement already satisfied: click>=8.0.0 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from black>=21->jupyter_black) (8.0.4)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from black>=21->jupyter_black) (0.4.3)
# Requirement already satisfied: packaging>=22.0 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from black>=21->jupyter_black) (23.0)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from black>=21->jupyter_black) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from black>=21->jupyter_black) (2.5.2)
# Requirement already satisfied: backcall in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (0.2.0)
# Requirement already satisfied: decorator in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (2.15.1)
# Requirement already satisfied: stack-data in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (4.8.0)
# Requirement already satisfied: appnope in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from ipython>=7->jupyter_black) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7->jupyter_black) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7->jupyter_black) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7->jupyter_black) (0.2.5)
# Requirement already satisfied: executing in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7->jupyter_black) (0.8.3)
# Requirement already satisfied: asttokens in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7->jupyter_black) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7->jupyter_black) (0.2.2)
# Requirement already satisfied: six in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from asttokens->stack-data->ipython>=7->jupyter_black) (1.16.0)

# %% [markdown]
# # Load data

# %%
df = pd.read_excel('Contact Center Data.xlsb', engine='pyxlsb')

# %%
df.head()
# Out:
#    Customer_Id    Source Customer_Profile Age_Group Gender         Purpose  \
# 0            1       SMS         Salaried   22 - 25   Male          Movies
# 1            2  Websites         Salaried   22 - 25   Male  Speed Response
# 2            3  Websites         Salaried   26 - 30   Male  Speed Response
# 3            4  Websites         Salaried   26 - 30   Male  Speed Response
# 4            5  Websites         Salaried   22 - 25   Male         Stylish
#
#   Product_Type                                           Comments  \
# 0       Tablet                                         Call drop.
# 1     Notebook                                          Call drop
# 2     Notebook  While assisting with the info, Customer discon...
# 3     Notebook  Customer had already ordered for G500 and enqu...
# 4       Tablet                                  Call disconnected
#
#                  Outcome
# 0      Call Disconnected
# 1      Call Disconnected
# 2      Call Disconnected
# 3  Product Specs Enquiry
# 4      Call Disconnected

# %%
df.columns.tolist()
# Out:
# ['Customer_Id',
#  'Source',
#  'Customer_Profile',
#  'Age_Group',
#  'Gender',
#  'Purpose',
#  'Product_Type',
#  'Comments',
#  'Outcome']

# %%
df.shape
# Out:
# (86410, 9)

# %% [markdown]
# # Customer_Id

# %%
df['Customer_Id'].nunique()
# Out:
# 52602

# %% [markdown]
# - Same customer/s have called multiple times - len(df) > number of customers

# %%
df['Customer_Id'].value_counts().describe(np.arange(0,1,0.1))
# Out:
# count    52602.000000
# mean         1.642713
# std          1.988710
# min          1.000000
# 0%           1.000000
# 10%          1.000000
# 20%          1.000000
# 30%          1.000000
# 40%          1.000000
# 50%          1.000000
# 60%          1.000000
# 70%          1.000000
# 80%          2.000000
# 90%          3.000000
# max         71.000000
# Name: Customer_Id, dtype: float64

# %% [markdown]
# - We can see that there are only few customers those have called more than 1 time
# - Majority of customers (70%) have called only 1 time

# %%
df['Customer_Id'].value_counts().describe(np.arange(0.9,1,0.01))
# Out:
# count    52602.000000
# mean         1.642713
# std          1.988710
# min          1.000000
# 50%          1.000000
# 90%          3.000000
# 91%          3.000000
# 92%          3.000000
# 93%          4.000000
# 94%          4.000000
# 95%          4.000000
# 96%          5.000000
# 97%          6.000000
# 98%          7.000000
# 99%         10.000000
# max         71.000000
# Name: Customer_Id, dtype: float64

# %% [markdown]
# - 10% people have called more than 3 times

# %%
df['Customer_Id'].value_counts().head(10)
# Out:
# 1107     71
# 18092    66
# 20847    57
# 14650    56
# 1023     49
# 25481    49
# 21286    43
# 35285    42
# 20850    40
# 18865    39
# Name: Customer_Id, dtype: int64

# %% [markdown]
# - top 10 caller Customer_Ids

# %% [markdown]
# # Source

# %%
df['Source'].nunique()
# Out:
# 7

# %%
plt.figure(figsize=(5,5))
df['Source'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Source')
plt.show()

# %%
df['Source'].unique().tolist()
# Out:
# ['SMS',
#  'Websites',
#  'Newspaper',
#  'Retail Store',
#  'Friends',
#  'Print Ads',
#  'TV Ads']

# %% [markdown]
# - There are 7 unique sources of calling

# %%
df['Source'].value_counts()
# Out:
# Websites        68947
# Newspaper       11120
# Friends          3538
# Retail Store     1713
# Print Ads         570
# SMS               333
# TV Ads            189
# Name: Source, dtype: int64

# %% [markdown]
# - Value counts of origin of call

# %%
(df['Source'].value_counts()*100/ df['Source'].value_counts().sum()).round(2)
# Out:
# Websites        79.79
# Newspaper       12.87
# Friends          4.09
# Retail Store     1.98
# Print Ads        0.66
# SMS              0.39
# TV Ads           0.22
# Name: Source, dtype: float64

# %% [markdown]
# - "Websites" and "Newspaper" are among top two sources
#     - ~ 80% of calls originate from "Websites"
#     - ~ 13% of calls originate from "Newspaper"
# - "SMS" and "TV Ads" are among the bottom two sources

# %% [markdown]
# # Customer_Profile

# %%
df['Customer_Profile'].nunique()
# Out:
# 6

# %%
plt.figure(figsize=(5,5))
df['Customer_Profile'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Customer_Profile')
plt.show()

# %%
df['Customer_Profile'].unique().tolist()
# Out:
# ['Salaried',
#  'Student',
#  '--Select--',
#  'Self Employed',
#  'Govt.Employed',
#  'House Wife']

# %% [markdown]
# - There are 6 unique customer profiles

# %%
df['Customer_Profile'].value_counts()
# Out:
# Salaried         52631
# Student          13488
# --Select--       10181
# Self Employed     9740
# Govt.Employed      274
# House Wife          96
# Name: Customer_Profile, dtype: int64

# %% [markdown]
# - Value counts of various customer profiles

# %%
(df['Customer_Profile'].value_counts()*100/ df['Customer_Profile'].value_counts().sum()).round(2)
# Out:
# Salaried         60.91
# Student          15.61
# --Select--       11.78
# Self Employed    11.27
# Govt.Employed     0.32
# House Wife        0.11
# Name: Customer_Profile, dtype: float64

# %% [markdown]
# - "Salaried" person as a customer forms the largest segment of callers in the group
# - "Student" as a customer is 2nd in the segment of callers with ~15% distribution
# - "--Select--" being ~12% - we do not know customer profile value of 12% people
# - "Self Employed" cover ~11% of the callers

# %% [markdown]
# # Age_Group

# %%
df['Age_Group'].nunique()
# Out:
# 8

# %%
plt.figure(figsize=(5,5))
df['Age_Group'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Age_Group')
plt.show()

# %%
df['Age_Group'].unique().tolist()
# Out:
# ['22 - 25',
#  '26 - 30',
#  '18 - 21',
#  '--Select--',
#  '31 - 40',
#  '< 18',
#  '41 - 50',
#  '> 51']

# %% [markdown]
# - There are 8 unique age groups

# %%
df['Age_Group'].value_counts()
# Out:
# 26 - 30       27357
# 22 - 25       23208
# 18 - 21       11554
# 31 - 40       10274
# --Select--     8028
# < 18           5373
# 41 - 50         507
# > 51            109
# Name: Age_Group, dtype: int64

# %% [markdown]
# - Value counts of various age groups

# %%
(df['Age_Group'].value_counts()*100/ df['Age_Group'].value_counts().sum()).round(2)
# Out:
# 26 - 30       31.66
# 22 - 25       26.86
# 18 - 21       13.37
# 31 - 40       11.89
# --Select--     9.29
# < 18           6.22
# 41 - 50        0.59
# > 51           0.13
# Name: Age_Group, dtype: float64

# %% [markdown]
# - "26 - 30" age group forms the largest segment of callers in the group being ~32%
# - "22 - 25" as a customer is 2nd in the segment of callers with ~27% distribution
# - "--Select--" being ~9% - we do not know age group value of 9% of the people

# %% [markdown]
# # Gender

# %%
df['Gender'].nunique()
# Out:
# 3

# %%
plt.figure(figsize=(5,5))
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Gender')
plt.show()

# %%
df['Gender'].unique().tolist()
# Out:
# ['Male', 'Female', 'Kid']

# %% [markdown]
# - There are 3 unique Gender values in data

# %%
df['Gender'].value_counts()
# Out:
# Male      82922
# Female     3380
# Kid         108
# Name: Gender, dtype: int64

# %% [markdown]
# - Value counts of various Genders

# %%
(df['Gender'].value_counts()*100/ df['Gender'].value_counts().sum()).round(2)
# Out:
# Male      95.96
# Female     3.91
# Kid        0.12
# Name: Gender, dtype: float64

# %% [markdown]
# - Males occupy ~96% of the distribution in Gender values
# - Female occupies ~3.9% of the distribution of Gender values
# - This data point is highly skewed towards Males suggesting very high number of Male callers as compared to Female callers

# %% [markdown]
# # Purpose

# %%
df['Purpose'].nunique()
# Out:
# 10

# %%
plt.figure(figsize=(5,5))
df['Purpose'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Purpose')
plt.show()

# %%
df['Purpose'].unique().tolist()
# Out:
# ['Movies',
#  'Speed Response',
#  'Stylish',
#  'Studies',
#  'Net Surfing',
#  'Battery life',
#  'Official',
#  'Gaming',
#  'Light Weight',
#  'Slim']

# %% [markdown]
# - There are 10 unique Purposes of a customer for calling

# %%
df['Purpose'].value_counts()
# Out:
# Net Surfing       32321
# Gaming            18864
# Speed Response    11897
# Official          10794
# Movies             5405
# Studies            4139
# Stylish            2211
# Battery life        499
# Light Weight        186
# Slim                 94
# Name: Purpose, dtype: int64

# %% [markdown]
# - Value counts of various Purposes

# %%
(df['Purpose'].value_counts()*100/ df['Purpose'].value_counts().sum()).round(2)
# Out:
# Net Surfing       37.40
# Gaming            21.83
# Speed Response    13.77
# Official          12.49
# Movies             6.26
# Studies            4.79
# Stylish            2.56
# Battery life       0.58
# Light Weight       0.22
# Slim               0.11
# Name: Purpose, dtype: float64

# %% [markdown]
# - ~37% of customers call for "Net Surfing" making it top Purpose for calling
# - ~22% of customers call for "Gaming" making it 2nd most Purpose for calling

# %% [markdown]
# # Product_Type

# %%
df['Product_Type'].nunique()
# Out:
# 7

# %%
plt.figure(figsize=(5,5))
df['Product_Type'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Product_Type')
plt.show()

# %%
df['Product_Type'].unique().tolist()
# Out:
# ['Tablet',
#  'Notebook',
#  'Mobile Phone',
#  'Desktop',
#  'Accessaries',
#  'AIO',
#  'Software And Peripherals']

# %% [markdown]
# - There are 7 unique Product_Type values in data

# %%
df['Product_Type'].value_counts()
# Out:
# Notebook                    66068
# Mobile Phone                 8074
# Tablet                       6109
# Accessaries                  2500
# Desktop                      1887
# AIO                          1249
# Software And Peripherals      523
# Name: Product_Type, dtype: int64

# %% [markdown]
# - Value counts of various product types

# %%
(df['Product_Type'].value_counts()*100/ df['Product_Type'].value_counts().sum()).round(2)
# Out:
# Notebook                    76.46
# Mobile Phone                 9.34
# Tablet                       7.07
# Accessaries                  2.89
# Desktop                      2.18
# AIO                          1.45
# Software And Peripherals     0.61
# Name: Product_Type, dtype: float64

# %% [markdown]
# - Notebook forms ~76% of the distribution in Product_Type values : making it top product for which people are calling
# - Mobile Phone forms ~9% of the distribution of Product_Type values : making it second most product for which people are calling

# %% [markdown]
# # Comments

# %%
df['Comments'].nunique()
# Out:
# 41943

# %%
df['Comments'].unique().tolist()[:10]
# Out:
# ['Call drop.',
#  'Call drop',
#  'While assisting with the info, Customer disconnected the call.',
#  'Customer had already ordered for G500 and enquired about it.',
#  'Call disconnected',
#  'Customer called to know about sheild warrenty assisted accordingly',
#  'Customer had a technical doubt.',
#  'Assisted with product specs, Already lead passed.',
#  'Customer enquired about the do gear offer registeration procedure.',
#  'Customer had a technical problem.']

# %%
def preprocess_comments(txt):
    # keep only letters and digits
    t = txt.lower()
    t = re.sub('[^a-z0-9]+', ' ', t).strip()
    return t

# %%
df['clean_comments'] = df['Comments'].astype(str).apply(lambda x:preprocess_comments(x))
df['clean_comments'].value_counts().head(10)
# Out:
# call drop                                    2844
# call disconnected                             915
# drop call                                     913
# assisted with offer details                   857
# customer enquired about offer                 828
# diwali offer enquiry                          783
# offer enquiry                                 749
# technical issue                               740
# customer enquired about diwali offer          657
# assisted with technical department number     519
# Name: clean_comments, dtype: int64

# %% [markdown]
# - Top 10 comments

# %%
(df['clean_comments'].value_counts()*100/ df['clean_comments'].value_counts().sum()).round(2).head(10)
# Out:
# call drop                                    3.29
# call disconnected                            1.06
# drop call                                    1.06
# assisted with offer details                  0.99
# customer enquired about offer                0.96
# diwali offer enquiry                         0.91
# offer enquiry                                0.87
# technical issue                              0.86
# customer enquired about diwali offer         0.76
# assisted with technical department number    0.60
# Name: clean_comments, dtype: float64

# %%
# !pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from WordCloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from WordCloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from WordCloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from matplotlib->WordCloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from matplotlib->WordCloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from matplotlib->WordCloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from matplotlib->WordCloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from matplotlib->WordCloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/nehagovekar/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)

# %% [markdown]
# - Top 10 comments percentage distribution
# - We can see almost 5% of the times call is being dropped or disconnected
# - We can see that people are calling for being assisted with various offers and other technical equiries

# %%
from wordcloud import WordCloud
comment = df['clean_comments'].astype(str)
wordcloud = WordCloud(width=800, height=400, max_words=200, background_color='white').generate(' '.join(comment))
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud for Offer Enquiry Comments')
plt.show()

# %% [markdown]
# # Outcome

# %%
df['Outcome'].nunique()
# Out:
# 20

# %%
plt.figure(figsize=(5,5))
df['Outcome'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Outcome')
plt.show()

# %%
df['Outcome'].unique().tolist()
# Out:
# ['Call Disconnected',
#  'Product Specs Enquiry',
#  'Offer Enquiry',
#  'Technical Issue',
#  'Price Enquiry',
#  'Complaint',
#  'BP Enquiry',
#  'Need Info an Email',
#  'Super Hot',
#  'Hot',
#  'Warm',
#  'Prank Call',
#  'Dealership Request',
#  'Prices High',
#  'Not Looking to Buy Now',
#  'Unhappy with Offer',
#  'Will Buy in Future',
#  'Cold',
#  'Better Competition Products',
#  'Does not Quality for Offer']

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# Offer Enquiry                  19674
# Complaint                      19669
# Product Specs Enquiry          14325
# Technical Issue                 9595
# Call Disconnected               8194
# Super Hot                       4612
# Price Enquiry                   3864
# Hot                             2715
# BP Enquiry                      1755
# Warm                             686
# Prank Call                       583
# Dealership Request               316
# Will Buy in Future               105
# Not Looking to Buy Now           104
# Cold                              95
# Prices High                       74
# Need Info an Email                17
# Unhappy with Offer                11
# Better Competition Products       10
# Does not Quality for Offer         6
# Name: count, dtype: int64

# %%
(df['Outcome'].value_counts()*100/ df['Outcome'].value_counts().sum()).round(2).head(10)
# Out:
# Outcome
# Offer Enquiry            22.77
# Complaint                22.76
# Product Specs Enquiry    16.58
# Technical Issue          11.10
# Call Disconnected         9.48
# Super Hot                 5.34
# Price Enquiry             4.47
# Hot                       3.14
# BP Enquiry                2.03
# Warm                      0.79
# Name: count, dtype: float64

# %% [markdown]
# - We can see that maximum people are either calling for enquiring about offer (23%) or raising a complaint (23%)
# - Call is being disconnected ~9% of the times

# %% [markdown]
# # Summary of Monovariate Analysis

# %% [markdown]
# TODO
# "Websites" and "Newspaper" are among top two sources
# ~ 80% of calls originate from "Websites"
# ~ 13% of calls originate from "Newspaper"
#
# "Salaried" person as a customer forms the largest segment of callers in the group
# "Student" as a customer is 2nd in the segment of callers with ~15% distribution
#
# "26 - 30" age group forms the largest segment of callers in the group being ~32%
# "22 - 25" as a customer is 2nd in the segment of callers with ~27% distribution
# "--Select--" being ~9% - we do not know age group value of 9% of the people
#
# Males occupy ~96% of the distribution in Gender values
# Female occupies ~3.9% of the distribution of Gender values
# This data point is highly skewed towards Males suggesting very high number of Male callers as compared to Female callers
#
# ~37% of customers call for "Net Surfing" making it top Purpose for calling
# ~22% of customers call for "Gaming" making it 2nd most Purpose for calling
#
# Notebook forms ~76% of the distribution in Product_Type values : making it top product for which people are calling
# Mobile Phone forms ~9% of the distribution of Product_Type values : making it second most product for which people are calling
#
# We can see almost 5% of the times call is being dropped or disconnected
# We can see that people are calling for being assisted with various offers and other technical enquiries

# %% [markdown]
# ```['Customer_Id',
#  'Source',
#  'Customer_Profile',
#  'Age_Group',
#  'Gender',
#  'Purpose',
#  'Product_Type',
#  'Comments',
#  'Outcome']```
